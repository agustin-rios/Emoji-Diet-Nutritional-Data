# %% [markdown]
# # Analisis: Emoji Diet Nutritional Data
# Para realizar este estudio es necesario descargar los datos de [la siguiente pagina](https://www.kaggle.com/ofrancisco/emoji-diet-nutritional-data-sr28?select=Emoji+Diet+Nutritional+Data+%28g%29+-+EmojiFoods+%28g%29.csv)

# %% [markdown]
# Importaremos librerias necesarias

# %%
import numpy as np
import pandas as pd
import os

# %% [markdown]
# Cargamos los datos

# %%
DATA_PATH = 'Herramienta\src\data\archive\Emoji Diet Nutritional Data (g) - EmojiFoods (g).csv'
nutritional_information = pd.read_csv(DATA_PATH)
nutritional_information.head(10)
# Out:
#           name emoji  Calories (kcal)  Carbohydrates (g)  Total Sugar (g)  \
# 0       grapes     🍇             0.69             0.1810           0.1548
# 1        melon     🍈             0.28             0.0658           0.0569
# 2   watermelon     🍉             0.30             0.0755           0.0620
# 3    tangerine     🍊             0.53             0.1334           0.1058
# 4        lemon     🍋             0.29             0.0932           0.0250
# 5       banana     🍌             0.89             0.2284           0.1223
# 6    pineapple     🍍             0.50             0.1312           0.0985
# 7    red apple     🍎             0.63             0.1522           0.1168
# 8  green apple     🍏             0.58             0.1361           0.0959
# 9         pear     🍐             0.57             0.1523           0.0975
#
#    Protein (g)  Total Fat (g)  Saturated Fat (g)  Monounsaturated Fat (g)  \
# 0       0.0072         0.0016            0.00054                  0.00007
# ...

# %%
nutritional_information.shape
# Out:
# (58, 35)

# %%
nutritional_information.columns
# Out:
# Index(['name', 'emoji', 'Calories (kcal)', 'Carbohydrates (g)',
#        'Total Sugar (g)', 'Protein (g)', 'Total Fat (g)', 'Saturated Fat (g)',
#        'Monounsaturated Fat (g)', 'Polyunsaturated Fat (g)', 'Total Fiber (g)',
#        'Cholesterol (mg)', 'Vitamin B6 (mg)', 'Vitamin A (IU)',
#        'Vitamin B12 (ug)', 'Vitamin C (mg)', 'Vitamin D (IU)',
#        'Vitamin E (IU)', 'Vitamin K (ug)', 'Thiamin (mg)', 'Riboflavin (mg)',
#        'Niacin (mg)', 'Folate (ug)', 'Pantothenic Acid (mg)', 'Choline (mg)',
#        'Calcium (g)', 'Copper (mg)', 'Iron (mg)', 'Magnesium (mg)',
#        'Manganese (mg)', 'Phosphorus (g)', 'Potassium (g)', 'Selenium (ug)',
#        'Sodium (g)', 'Zinc (mg)'],
#       dtype='object')

# %%
# List of items in column with name 'name'
nutritional_information['name'].tolist()
# Out:
# ['grapes',
#  'melon',
#  'watermelon',
#  'tangerine',
#  'lemon',
#  'banana',
#  'pineapple',
#  'red apple',
#  'green apple',
#  'pear',
#  'peach',
#  'cherries',
#  'strawberry',
#  'kiwifruit',
#  'tomato',
#  'avocado',
#  'eggplant',
#  'potato',
#  'carrot',
#  'corn',
#  'hot pepper',
#  'cucumber',
#  'mushroom',
#  'peanuts',
#  'chestnut',
#  'bread',
#  'croissant',
#  'french bread',
#  'pancakes',
#  'cheese',
#  'beef',
#  'chicken',
#  'bacon',
#  'hamburger',
#  'french fries',
#  'pizza',
#  'hotdog',
#  'taco',
#  'burrito',
#  'popcorn',
#  'rice crackers',
#  'rice',
#  'spaghetti',
#  'fried shrimp',
#  'ice cream',
#  'doughnut',
#  'cookie',
#  'cake',
#  'chocolate bar',
#  'candy',
#  'custard flan',
#  'honey',
#  'milk',
#  'black tea',
#  'sake',
#  'champagne',
#  'red wine',
#  'beer']

# %%
# Search for fruit with name xxxx in nutritional_information
nutritional_information[nutritional_information['name'] == 'beer']
# Out:
#     name emoji  Calories (kcal)  Carbohydrates (g)  Total Sugar (g)  \
# 57  beer     🍺             0.43             0.0355              0.0
#
#     Protein (g)  Total Fat (g)  Saturated Fat (g)  Monounsaturated Fat (g)  \
# 57       0.0046            0.0                0.0                      0.0
#
#     Polyunsaturated Fat (g)  ...  Calcium (g)  Copper (mg)  Iron (mg)  \
# 57                      0.0  ...         0.04      0.00005     0.0002
#
#     Magnesium (mg)  Manganese (mg)  Phosphorus (g)  Potassium (g)  \
# 57            0.06         0.00008            0.14           0.27
#
#     Selenium (ug)  Sodium (g)  Zinc (mg)
# 57          0.006        0.04     0.0001
#
# [1 rows x 35 columns]
